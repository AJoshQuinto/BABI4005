# %% [markdown]
# # Cleaning Script
# Small Cleaning script to prep the data prior to analysis. This file cleans the Regular season dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np
import os

# %%
# The idea of changing encoding and delimeter were found through ChatGPT as importing the data using the previous method showed errors.
reg = pd.read_csv("../RawData/Regular_Season.csv", encoding="ISO-8859-1", delimiter= ";")

# %% [markdown]
# ## Summary of Dataset

# %%
reg.head()
# Out:
#    Rk            Player   Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  \
# 0   1  Precious Achiuwa  PF-C   24  TOT  74  18  21.9  3.2   6.3  ...  0.616
# 1   1  Precious Achiuwa     C   24  TOR  25   0  17.5  3.1   6.8  ...  0.571
# 2   1  Precious Achiuwa    PF   24  NYK  49  18  24.2  3.2   6.1  ...  0.643
# 3   2       Bam Adebayo     C   26  MIA  71  71  34.0  7.5  14.3  ...  0.755
# 4   3      Ochai Agbaji    SG   23  TOT  78  28  21.0  2.3   5.6  ...  0.661
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.6  4.0   6.6  1.3  0.6  0.9  1.1  1.9   7.6
# 1  2.0  3.4   5.4  1.8  0.6  0.5  1.2  1.6   7.7
# 2  2.9  4.3   7.2  1.1  0.6  1.1  1.1  2.1   7.6
# 3  2.2  8.1  10.4  3.9  1.1  0.9  2.3  2.2  19.3
# 4  0.9  1.8   2.8  1.1  0.6  0.6  0.8  1.5   5.8
#
# [5 rows x 30 columns]

# %%
reg.describe()
# Out:
#                Rk         Age           G          GS          MP          FG  \
# count  735.000000  735.000000  735.000000  735.000000  735.000000  735.000000
# mean   282.209524   26.155102   40.880272   18.440816   18.264762    2.972789
# std    166.858903    4.371745   25.581293   25.024108    9.735524    2.356999
# min      1.000000   19.000000    1.000000    0.000000    0.500000    0.000000
# 25%    140.500000   23.000000   17.000000    0.000000   10.600000    1.300000
# 50%    290.000000   25.000000   41.000000    5.000000   17.200000    2.300000
# 75%    423.500000   29.000000   64.500000   29.000000   26.450000    4.150000
# max    572.000000   39.000000   84.000000   82.000000   37.800000   11.500000
#
#               FGA         FG%          3P         3PA  ...         FT%  \
# count  735.000000  735.000000  735.000000  735.000000  ...  735.000000
# mean     6.423401    0.442687    0.909116    2.582449  ...    0.689493
# ...

# %%
print(reg.dtypes)
# Out:
# Rk          int64
# Player     object
# Pos        object
# Age         int64
# Tm         object
# G           int64
# GS          int64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# dtype: object

# %% [markdown]
# ## Rounding the Numeric columns to 2 decimal places

# %%
reg = reg.round(2)

# %%
reg.head()
# Out:
#    Rk            Player   Pos  Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0   1  Precious Achiuwa  PF-C   24  TOT  74  18  21.9  3.2   6.3  ...  0.62
# 1   1  Precious Achiuwa     C   24  TOR  25   0  17.5  3.1   6.8  ...  0.57
# 2   1  Precious Achiuwa    PF   24  NYK  49  18  24.2  3.2   6.1  ...  0.64
# 3   2       Bam Adebayo     C   26  MIA  71  71  34.0  7.5  14.3  ...  0.76
# 4   3      Ochai Agbaji    SG   23  TOT  78  28  21.0  2.3   5.6  ...  0.66
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.6  4.0   6.6  1.3  0.6  0.9  1.1  1.9   7.6
# 1  2.0  3.4   5.4  1.8  0.6  0.5  1.2  1.6   7.7
# 2  2.9  4.3   7.2  1.1  0.6  1.1  1.1  2.1   7.6
# 3  2.2  8.1  10.4  3.9  1.1  0.9  2.3  2.2  19.3
# 4  0.9  1.8   2.8  1.1  0.6  0.6  0.8  1.5   5.8
#
# [5 rows x 30 columns]

# %% [markdown]
# # Removing Secondary positions
# For example if a player played both the Center (C) position and the Power Forward (PF) position it would only take their "primary" position. In this case, the first position listed will be thier "Primary" position

# %%
reg["Pos"] = reg["Pos"].str.split("-").str[0]

# %%
reg.head()
# Out:
#    Rk            Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0   1  Precious Achiuwa  PF   24  TOT  74  18  21.9  3.2   6.3  ...  0.62
# 1   1  Precious Achiuwa   C   24  TOR  25   0  17.5  3.1   6.8  ...  0.57
# 2   1  Precious Achiuwa  PF   24  NYK  49  18  24.2  3.2   6.1  ...  0.64
# 3   2       Bam Adebayo   C   26  MIA  71  71  34.0  7.5  14.3  ...  0.76
# 4   3      Ochai Agbaji  SG   23  TOT  78  28  21.0  2.3   5.6  ...  0.66
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.6  4.0   6.6  1.3  0.6  0.9  1.1  1.9   7.6
# 1  2.0  3.4   5.4  1.8  0.6  0.5  1.2  1.6   7.7
# 2  2.9  4.3   7.2  1.1  0.6  1.1  1.1  2.1   7.6
# 3  2.2  8.1  10.4  3.9  1.1  0.9  2.3  2.2  19.3
# 4  0.9  1.8   2.8  1.1  0.6  0.6  0.8  1.5   5.8
#
# [5 rows x 30 columns]

# %%
print(type(reg))  # Check if reg is a DataFrame or a string
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
folder_name = "CleanData"

os.makedirs(folder_name, exist_ok=True)

cleaned_file_path = os.path.join(folder_name, "Regular_Season_Cleaned.csv")
reg.to_csv(cleaned_file_path, index=False)

print(f"File saved at: {cleaned_file_path}")
# Out:
# File saved at: CleanData\Regular_Season_Cleaned.csv
